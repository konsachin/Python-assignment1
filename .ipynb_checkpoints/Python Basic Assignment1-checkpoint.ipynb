# %% [raw]
# # Q1) Explain the key features of Python that make it a popular choice for programming
#
# Python is a highly popular programming language, known for its versatility, ease of use, and wide range of applications. Here are some of the key features that contribute to its popularity:
#
# 1. Readability and Simplicity
# Clear Syntax: Python's syntax is designed to be readable and straightforward, which makes it easier to learn and understand.
# Less Code: Python often requires fewer lines of code to accomplish the same tasks compared to other languages like Java or C++.
#
# 2. Interpreted Language
# No Compilation Step: Python is an interpreted language, meaning code can be run as soon as it's written without the need for a separate compilation step.
# Interactive Mode: Python supports an interactive mode which allows for interactive testing and debugging of code.
#
# 3. Versatility
# Multi-Paradigm: Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
# Extensive Libraries: Python has a vast standard library and many third-party libraries, making it suitable for a wide range of applications from web development to scientific computing.
#
# 4. Portability
# Cross-Platform Compatibility: Python code can run on various operating systems like Windows, macOS, Linux, and more, with little to no modification.
#
#
# 5. Data Science and Machine Learning
# Popular Libraries: Python is the language of choice for data science and machine learning, with powerful libraries such as Pandas, NumPy, SciPy, Scikit-Learn, TensorFlow, and PyTorch.
# Visualization Tools: Libraries like Matplotlib and Seaborn make it easy to create visualizations and gain insights from data.
#
#
# 6. Automation and Scripting
# Automating Tasks: Python is commonly used for scripting to automate repetitive tasks and processes, from simple file manipulations to complex system administration tasks.

# %% [raw]
# Q2) Describe the role of predefined keywords in Python and provide examples of how they are used in a program
#
# Role of Predefined Keywords
# 1)Control Flow: Keywords like if, else, elif, while, for, break, continue, and pass are used to control the flow of the program.
# 2)Data Types and Structures: Keywords such as None, True, False, class, def, lambda, return, yield, and global are used to define data types, functions, and classes.
# 3)Exception Handling: Keywords like try, except, finally, raise, assert, and with are used for handling exceptions and resource management.
# 4)Logical and Arithmetic Operations: Keywords like and, or, not, is, and in are used for logical and membership operations.
# 5)Context Management: Keywords like with are used to ensure proper acquisition and release of resources.
#
# 1. Control Flow
# # Example of if, elif, and else
# x = 10
# if x < 0:
#     print("Negative")
# elif x == 0:
#     print("Zero")
# else:
#     print("Positive")
#
#  2. Looping and Control Statements python
#
# # Example of for, while, break, continue, and pass
# for i in range(5):
#     if i == 3:
#         continue  # Skip the rest of the code inside the loop for this iteration
#     print(i)
#
# i = 0
# while i < 5:
#     if i == 3:
#         break  # Exit the loop
#     print(i)
#     i += 1
#
# 3. Function Definition and Return
# # Example of def, return, and lambda
# def square(x):
#     return x * x
#
# result = square(5)
# print(result)  # Output: 25
#
# # Using lambda for a small anonymous function
# square_lambda = lambda x: x * x
# print(square_lambda(5))  # Output: 25
#
# 4. Exception Handling
# # Example of try, except, and finally
# try:
#     result = 10 / 0
# except ZeroDivisionError:
#     print("Cannot divide by zero")
# finally:
#     print("This block is always executed")

# %% [raw]
# Q3) Compare and contrast mutable and immutable objects in Python with examples
#
# Mutable object :- List , Dictionary, Set
#
# List :
# my_list = [1, 2, 3]
# my_list.append(4)  # Modifying the list
# print(my_list)     # Output: [1, 2, 3, 4]
#
# Dict:
# my_dict = {'a': 1, 'b': 2}
# my_dict['c'] = 3  # Adding a new key-value pair
# print(my_dict)    # Output: {'a': 1, 'b': 2, 'c': 3}
#
# Set :
# my_set = {1, 2, 3}
# my_set.add(4)  # Adding an element to the set
# print(my_set)  # Output: {1, 2, 3, 4}
#
# Immutable Objects : String, Tuple , forzen_set
#
# String:
# my_string = "hello"
# new_string = my_string + " world"  # Creating a new string
# print(new_string)  # Output: "hello world"
#
# Tuple:
# my_tuple = (1, 2, 3)
# new_tuple = my_tuple + (4,)  # Creating a new tuple
# print(new_tuple)  # Output: (1, 2, 3, 4)
#
# forzen_set :
#
# my_frozen_set = frozenset([1, 2, 3])
# new_frozen_set = my_frozen_set.union([4])  # Creating a new frozen set
# print(new_frozen_set)  # Output: frozenset({1, 2, 3, 4})

# %% [raw]
# #Q4) Discuss the different types of operators in Python and provide examples of how they are used
#
#
# 1. Arithmetic Operators
# #These operators are used to perform basic mathematical operations.
#
#
# Addition (+)
#
# a = 5
# b = 3
# result = a + b  # result is 8
#
#
# Subtraction (-)
#
# result = a - b  # result is 2
#
# Multiplication (*)
#
# result = a * b  # result is 15
#
#
# Division (/)
# result = a / b  # result is 1.6666666666666667
#
# 2. Comparison Operators
#
# Equal to (==)
#
# result = (a == b)  # result is False
#
#
# Not equal to (!=)
#
# result = (a != b)  # result is True
#
# Greater than (>)
#
# result = (a > b)  # result is True
#
# Less than (<)
# result = (a < b)  # result is False
#
# Greater than or equal to (>=)
# result = (a >= b)  # result is True
#
# Less than or equal to (<=)
# result = (a <= b)  # result is False
#
#
# Logical Operators
# Logical AND (and)
# result = (a > 2 and b < 5)  # result is True
#
#
# Logical OR (or)
# result = (a < 2 or b > 1)  # result is True
#
#
# Logical NOT (not)
# result = not(a < 2)  # result is True
#
# 5. Bitwise Operators : AND (&) , OR (|) , XOR (^), NOT (~) , Left Shift (<<), Right Shift (>>)

# %% [raw]
# Q5) Explain the concept of type casting in Python with examples
#
# Common Type Casting Functions
# int(): Converts a value to an integer.
# float(): Converts a value to a floating-point number.
# str(): Converts a value to a string.
# list(): Converts a value to a list.
# tuple(): Converts a value to a tuple.
# set(): Converts a value to a set.
# dict(): Converts a value to a dictionary.
# Examples of Explicit Type Casting
#
# Converting a float to an integer
# x = 5.7
# y = int(x)  # y is now 5
# print(y)    # Output: 5
#
# Converting a string to a float
# s = "3.14"
# pi = float(s)  # pi is now 3.14
# print(pi)      # Output: 3.14
#
# Converting an integer to a string
# num = 100
# num_str = str(num)  # num_str is now "100"
# print(num_str)      # Output: "100"
#
# Converting a list to a tuple
# lst = [1, 2, 3]
# tpl = tuple(lst)  # tpl is now (1, 2, 3)
# print(tpl)        # Output: (1, 2, 3)
#
# Converting a tuple to a list
# tpl = (1, 2, 3)
# lst = list(tpl)  # lst is now [1, 2, 3]
# print(lst)       # Output: [1, 2, 3]
#
# Converting a list of key-value pairs to a dictionary
# pairs = [('a', 1), ('b', 2)]
# dct = dict(pairs)  # dct is now {'a': 1, 'b': 2}
# print(dct)         # Output: {'a': 1, 'b': 2}
#
# Implicit Type Casting
# Examples of Implicit Type Casting
#
# Mixing integers and floats
# x = 10   # integer
# y = 2.5  # float
# result = x + y  # y is implicitly converted to float, result is 12.5
# print(result)   # Output: 12.5
#
# Division operation
# a = 7
# b = 2
# result = a / b  # a and b are implicitly converted to floats, result is 3.5
# print(result)   # Output: 3.5

# %% [raw]
# Q6) How do conditional statements work in Python? Illustrate with examples
#
# Conditional statements in Python allow you to execute specific blocks of code based on
# whether a condition is true or false. These statements are essential for controlling the flow of a program.
# The primary conditional statements in Python are if, elif, and else.
#
# #Example 1: Simple if Statement
# age = 18
#
# if age >= 18:
#     print("You are an adult.")
# # Output: You are an adult.
#
# #Example 2: if-else Statement
# python
# age = 16
#
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
# # Output: You are a minor.
#
# #Example 3: if-elif-else Statement
# age = 10
#
# if age >= 18:
#     print("You are an adult.")
# elif age >= 13:
#     print("You are a teenager.")
# else:
#     print("You are a child.")
# # Output: You are a child.
#
#
# #Example 4: Nested Conditional Statements
# number = 15
#
# if number > 0:
#     if number % 2 == 0:
#         print("The number is positive and even.")
#     else:
#         print("The number is positive and odd.")
# else:
#     if number == 0:
#         print("The number is zero.")
#     else:
#         print("The number is negative.")
# # Output: The number is positive and odd.
