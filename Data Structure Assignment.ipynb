# %%
# 1) Discuss string slicing and provide examples

#String slicing is a technique used to extract a portion of a string using a specified range of indices. In Python, slicing can be done using the syntax string[start:stop:step], where:

#start is the index where the slice begins (inclusive).
#stop is the index where the slice ends (exclusive).
#step is the interval between each character in the slice.

b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [raw]
# #Q2) Explain the key features of lists in Python
#
# #1) Ordered:
#
# #Lists maintain the order of elements. The elements can be accessed by their index, starting from 0.
#
# fruits = ['apple', 'banana', 'cherry']
# print(fruits[0])  # Output: apple
#
# 2) Mutable:
#
# Lists can be modified after their creation. You can change, add, or remove elements.
# fruits = ['apple', 'banana', 'cherry']
# fruits[1] = 'blueberry'
# print(fruits)  # Output: ['apple', 'blueberry', 'cherry']
#
# 3)Dynamic:
#
# Lists can grow and shrink in size. You can add or remove items dynamically.
#
# fruits.append('date')
# print(fruits)  # Output: ['apple', 'blueberry', 'cherry', 'date']
#
# fruits.remove('apple')
# print(fruits)  # Output: ['blueberry', 'cherry', 'date']
#
# 4) Slicing and Indexing:
#
# Lists support slicing and indexing to access sub-parts of the list.
#
# numbers = [0, 1, 2, 3, 4, 5]
# print(numbers[1:4])  # Output: [1, 2, 3]
#
# 5) Comprehensive Methods:
#
# Lists come with a variety of built-in methods for common operations like adding, removing, sorting, and reversing elements.
#
# fruits = ['apple', 'banana', 'cherry']
# fruits.append('date')
# fruits.remove('banana')
# fruits.sort()
# print(fruits)  # Output: ['apple', 'cherry', 'date']

# %% [raw]
# Q3) Describe how to access, modify, and delete elements in a list with examples
#
# Accessing, modifying, and deleting elements in a list are fundamental operations in Python. Here are detailed descriptions and examples of each operation:
#
# 1)Accessing a Single Element
#
# fruits = ['apple', 'banana', 'cherry']
# print(fruits[0])  # Output: apple
# print(fruits[2])  # Output: cherry
#
# 2) Accessing Multiple Elements (Slicing)
# fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# print(fruits[1:4])  # Output: ['banana', 'cherry', 'date']
# print(fruits[:3])   # Output: ['apple', 'banana', 'cherry']
# print(fruits[2:])   # Output: ['cherry', 'date', 'elderberry']
# print(fruits[-2:])  # Output: ['date', 'elderberry']
#
# #modify
# 1)Modifying a Single Element
#
# fruits = ['apple', 'banana', 'cherry']
# fruits[1] = 'blueberry'
# print(fruits)  # Output: ['apple', 'blueberry', 'cherry']
#
# 2) modifying a multiple elements
# numbers = [0, 1, 2, 3, 4, 5]
# numbers[1:3] = [9, 8]
# print(numbers)  # Output: [0, 9, 8, 3, 4, 5]
#
#
# #Deleting Elements
#
# #Using del Statement
# fruits = ['apple', 'banana', 'cherry']
# del fruits[1]
# print(fruits)  # Output: ['apple', 'cherry']
#
# # Deleting multiple elements using slicing
# numbers = [0, 1, 2, 3, 4, 5]
# del numbers[1:4]
# print(numbers)  # Output: [0, 4, 5]
#
# #Using remove() Method
# fruits = ['apple', 'banana', 'cherry', 'banana']
# fruits.remove('banana')
# print(fruits)  # Output: ['apple', 'cherry', 'banana']
#
# #Using pop() Method
# fruits = ['apple', 'banana', 'cherry']
# popped_fruit = fruits.pop(1)
# print(popped_fruit)  # Output: banana
# print(fruits)  # Output: ['apple', 'cherry']
#
# last_fruit = fruits.pop()
# print(last_fruit)  # Output: cherry
# print(fruits)  # Output: ['apple']

# %% [raw]
# Q4) Compare and contrast tuples and lists with examples
#
# Key Difference Between List and Tuple. The main difference between tuples and lists is that tuples can't be changed after they're created, but lists can be modified. Tuples use less memory than lists. They are also a bit faster, especially when you're just looking up values
#
# Tuples :
#
# Immutability: Tuples are immutable, meaning once a tuple is created, its elements cannot be changed, added, or removed.
#
# Lists :
# Mutability:Lists are mutable, meaning their elements can be changed, added, or removed.
#
# #example
# my_list = [1, 2, 3]
# my_list[1] = 4
# print(my_list)  # Output: [1, 4, 3]
#
# my_tuple = (1, 2, 3)
# # my_tuple[1] = 4  # This would raise a TypeError

# %% [raw]
# Q5) Describe the key features of sets and provide examples of their use
#
# Sets in Python are a collection type that stores unordered, unique elements. They are useful for operations that involve membership tests, deduplication, and set operations like unions and intersections. Here are the key features of sets along with examples of their use:
#
# !)Unordered:
#
# Sets do not maintain any particular order of elements. This means you cannot access elements using an index.
# my_set = {1, 2, 3}
# # print(my_set[0])  # This would raise a TypeError
#
# 2)Unique Elements:
#
# Sets automatically discard duplicate elements
# my_set = {1, 2, 2, 3, 4, 4}
# print(my_set)  # Output: {1, 2, 3, 4}
#
# 3)Mutable:
#
# Sets are mutable, meaning you can add or remove elements. However, the elements themselves must be immutable (e.g., numbers, strings, tuples).
# my_set = {1, 2, 3}
# my_set.add(4)
# print(my_set)  # Output: {1, 2, 3, 4}
#
# my_set.remove(2)
# print(my_set)  # Output: {1, 3, 4}
#
# #Sets support mathematical operations like union, intersection, difference, and symmetric difference.
# set_a = {1, 2, 3}
# set_b = {3, 4, 5}
#
# print(set_a | set_b)  # Union: {1, 2, 3, 4, 5}
# print(set_a & set_b)  # Intersection: {3}
# print(set_a - set_b)  # Difference: {1, 2}
# print(set_a ^ set_b)  # Symmetric Difference: {1, 2, 4, 5}

# %% [raw]
# Q6)Discuss the use cases of tuples and sets in Python programming
#
# Tuples:
#
# Use tuples for immutable collections, returning multiple values from functions, dictionary keys, and grouping related data.
# Tuples are more memory efficient and can be used in contexts where immutability is crucial.
#
# Sets:
#
# Use sets for collections of unique items, fast membership testing, and performing set operations like union, intersection, and difference.
# Sets are ideal for scenarios where duplicates need to be removed or avoided, and for operations requiring the mathematical properties of sets.

# %% [raw]
# Q7) Describe how to add, modify, and delete items in a dictionary with examples
#
# Adding a Single Item:
# my_dict = {'name': 'Alice', 'age': 25}
# my_dict['city'] = 'New York'
# print(my_dict)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York'}
#
# Adding Multiple Items:
# my_dict = {'name': 'Alice', 'age': 25}
# my_dict.update({'city': 'New York', 'job': 'Engineer'})
# print(my_dict)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York', 'job': 'Engineer'}
#
#
# Modifying Items
# You can modify items in a dictionary by reassigning a value to an existing key.
#
# Modifying a Single Item:
# my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}
# my_dict['age'] = 26
# print(my_dict)  # Output: {'name': 'Alice', 'age': 26, 'city': 'New York'}
#
# Modifying Multiple Items:
#
# my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}
# my_dict.update({'age': 26, 'city': 'Boston'})
# print(my_dict)  # Output: {'name': 'Alice', 'age': 26, 'city': 'Boston'}
#
# Deleting Items
# You can delete items from a dictionary using the del statement, pop() method, or popitem() method.
#
# Using del Smy_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}
# del my_dict['age']
# print(my_dict)  # Output: {'name': 'Alice', 'city': 'New York'}
#
# Using pop() Method:
# my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}
# age = my_dict.pop('age')
# print(age)      # Output: 25
# print(my_dict)  # Output: {'name': 'Alice', 'city': 'New York'}
#
# Using popitem() Method:
#
# my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}
# item = my_dict.popitem()
# print(item)     # Output: ('city', 'New York')
# print(my_dict)  # Output: {'name': 'Alice', 'age': 25}

# %% [raw]
# Q8) Discuss the importance of dictionary keys being immutable and provide examples.
#
# In Python, dictionary keys must be immutable. This means that the data type of the key must not change over its lifetime. The immutability of keys is essential for maintaining the integrity and performance of dictionaries. Here's why immutable keys are important and some examples to illustrate this concept:
#
# # Using strings as keys
# my_dict = {"name": "Alice", "age": 30}
# print(my_dict["name"])  # Output: Alice
#
# # Using numbers as keys
# my_dict = {1: "one", 2: "two", 3: "three"}
# print(my_dict[2])  # Output: two
#
# # Using tuples as keys
# my_dict = {(1, 2): "a", (3, 4): "b"}
# print(my_dict[(1, 2)])  # Output: a
